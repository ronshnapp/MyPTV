# %%
import os, sys
sys.path.append('./../')

from calibrate_mod import calibrate
from imaging_mod import camera, img_system


import numpy as np
import matplotlib.pyplot as plt
from skimage import color, io
from skimage import io

# %% [markdown]
# # estimate camera internal parameters:

# %%
# get two calication points  with having a good initial calibration condition:
calPointsParams = {1: [(0., -25., 0.), (1570, 1490)],
                   2: [(0.,  85., 0.), (1567, 419) ]}

# %%
img_internalCal = color.rgb2gray(io.imread('CalInternalParams.jpg'))


fig, ax = plt.subplots()
fig.set_size_inches(8,8)
ax.imshow(img_internalCal, cmap='gray')

for k in calPointsParams.keys():
    ax.plot(calPointsParams[k][1][0], calPointsParams[k][1][1], 'ob', ms=4)

# %%
# use the calibration to estimate the focal distance f:

labCoordsCal = [calPointsParams[k][0] for k in sorted(calPointsParams.keys())]
imgCoordsCal = [calPointsParams[k][1] for k in sorted(calPointsParams.keys())]
    


cam_resolution = 3264, 2448

camCal = camera('camCal', cam_resolution)


# give initial guess for camera parameters:
camCal.O = np.array([7., 1.35, 312.0])
camCal.theta = np.array([3.14, 0.0, 0.0])
camCal.f=3020
camCal.calc_R()

calCal = calibrate(camCal,labCoordsCal, imgCoordsCal)

# plot initial guess

fig, ax = plt.subplots()
calCal.plot_proj(ax=ax)
ax.set_xlim(1400,1800)
# Out:
# (1400.0, 1800.0)

# %% [markdown]
# # mark calibration points:

# %% [markdown]
# ##### data from the calibration images extracted manually:

# %%
# for cropped images:

calPoints_1 = {1: [(0. , 0., 0.), (562, 1024)],
               2: [(30., 0., 0.), (780, 981) ],
               3: [(60., 0., 0.), (986, 942) ],
               4: [(0., 40., 0.), (548, 729) ],
               5: [(30.,40., 0.), (776, 694) ],
               6: [(60.,40., 0.), (991, 662) ],
               7: [(0., 70., 0.), (536, 492) ],
               8: [(30.,70., 0.), (773, 464) ],
               9: [(60.,70., 0.), (996, 438) ]}


calPoints_2 = {1: [(0. , 0., 0.), (799, 932)  ],
               2: [(30., 0., 0.), (993, 991)  ],
               3: [(60., 0., 0.), (1201,1056) ],
               4: [(0., 40., 0.), (796, 664)  ],
               5: [(30.,40., 0.), (1000, 716) ],
               6: [(60.,40., 0.), (1219, 773) ],
               7: [(0., 70., 0.), (795, 449)  ],
               8: [(30.,70., 0.), (1007, 494) ],
               9: [(60.,70., 0.), (1236, 544) ]}

# %%
# for uncropped images:

calPoints_1 = {1: [(0. , 0., 0.), (1099, 1741)],
               3: [(60., 0., 0.), (1690, 1862)],
               5: [(30.,40., 0.), (1415, 1411)],
               7: [(0., 70., 0.), (1121, 1052)],
               9: [(60.,70., 0.), (1781, 1138)]}


calPoints_2 = {1: [(0. , 0., 0.), (1017, 1595) ],
               3: [(60., 0., 0.), (1582, 1550) ],
               5: [(30.,40., 0.), (1314, 1188) ],
               7: [(0., 70., 0.), (1008, 888 ) ],
               9: [(60.,70., 0.), (1623, 868 ) ]}

# %%
# %matplotlib notebook

# %%
fig = plt.figure
plt.imshow(img1, cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# #### Show the images and mark the given coordinates:

# %%
img1 = color.rgb2gray(io.imread('cal1.jpg'))
img2 = color.rgb2gray(io.imread('cal2.jpg'))

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10,8)

ax[0].imshow(img1, cmap='gray')
ax[1].imshow(img2, cmap='gray')


for k in calPoints_1:
    ax[0].plot(calPoints_1[k][1][0], calPoints_1[k][1][1], 'bo')
    ax[0].text(calPoints_1[k][1][0], calPoints_1[k][1][1], str(k))
    
    
for k in calPoints_2:
    ax[1].plot(calPoints_2[k][1][0], calPoints_2[k][1][1], 'bo')
    ax[1].text(calPoints_2[k][1][0], calPoints_2[k][1][1], str(k))
# Out:
# <img src="data:image/png;base64,..." width="720">

# %% [markdown]
# # Calibrate cameras:

# %% [markdown]
# ### camera 1:

# %%
imgCoords_1 = [np.array(calPoints_1[k][1]) for k in sorted(calPoints_1)]
labCoords1 = [np.array(calPoints_1[k][0]) for k in sorted(calPoints_1)]

cam_resolution = 3264, 2448

cam1 = camera('cam1', img1.shape)


# give initial guess for camera parameters:
cam1.O = np.array([100.0, 70.0, 300.0])
cam1.theta = np.array([3.15, -0.15, -0.15])
cam1.f=3020
cam1.calc_R()

cal1 = calibrate(cam1,labCoords1, imgCoords_1)

# plot initial guess
cal1.plot_proj()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# optimize camera parameters three times and plot:
for i in range(3):
    cal1.searchCalibration()
    
#cal1.searchCalibration(fix_f=False)

cal1.plot_proj()
# Out:
# Optimization terminated successfully.
#          Current function value: 16.118073
#          Iterations: 690
#          Function evaluations: 1115
# Optimization terminated successfully.
#          Current function value: 6.623352
#          Iterations: 1228
#          Function evaluations: 1890
# Optimization terminated successfully.
#          Current function value: 6.009906
#          Iterations: 723
#          Function evaluations: 1145
# <img src="data:image/png;base64,..." width="432">

# %%
print('O: ', cam1.O)
print('theta: ', cam1.theta)
print('f: ', cam1.f)
# Out:
# O:  [ 91.42164282 138.70490398 253.74142724]
# theta:  [ 3.41795745 -0.19550794 -0.0947422 ]
# f:  3020

# %% [markdown]
# ### camera 2:

# %%
imgCoords_2 = [np.array(calPoints_2[k][1]) for k in sorted(calPoints_2)]
labCoords2 = [np.array(calPoints_2[k][0]) for k in sorted(calPoints_2)]

cam_resolution = 3264, 2448

cam2 = camera('cam2', img2.shape)


# give initial guess for camera parameters:
cam2.O = np.array([-50.0, 50.0, 320.0])
cam2.theta = np.array([3.15, 0.35, 0.15])
cam2.f = 3020
cam2.calc_R()

cal2 = calibrate(cam2,labCoords2, imgCoords_2)

# plot initial guess
cal2.plot_proj()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# optimize camera parameters three times and plot:
for i in range(3):
    cal2.searchCalibration()
    
#cal2.searchCalibration(fix_f=False)
    
# plot initial guess
cal2.plot_proj()
# Out:
# Optimization terminated successfully.
#          Current function value: 6.900087
#          Iterations: 1031
#          Function evaluations: 1608
# Optimization terminated successfully.
#          Current function value: 6.899582
#          Iterations: 275
#          Function evaluations: 465
# Optimization terminated successfully.
#          Current function value: 6.225261
#          Iterations: 1394
#          Function evaluations: 2169
# <img src="data:image/png;base64,..." width="432">

# %%
print('O: ', cam2.O)
print('theta: ', cam2.theta)
print('f: ', cam2.f)
# Out:
# O:  [-45.01833764 116.29013589 278.46513604]
# theta:  [ 3.42571886  0.35827407 -0.04549833]
# f:  3020

# %%
# Finding the location of coordinate point 4:

# %%
particleCoords = {0: (1107, 1363),
                  1: (1012, 1202)}

fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10,8)

ax[0].imshow(img1, cmap='gray')
ax[1].imshow(img2, cmap='gray')

for k in particleCoords.keys():
    ax[k].plot(particleCoords[k][0], particleCoords[k][1], 'bo', ms=3)
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# setting up an imaging system for stereo matching:
imgSys = img_system([cam1, cam2])


# solving stereo matching:
d_max = 500.0
results = imgSys.stereo_match(particleCoords, d_max)

print(results)
# Out:
# (array([144.53583   , -40.68117526,  68.13194264]), {0, 1}, 60.35214360536093)

# %%
r = cam1.get_r(1099, 1741)
print(r)
a=0.11
print(r*a + cam1.O)
# Out:
# [-839.61785582 2430.44476326 2597.54925053]
# [ -0.93632132 406.05382794 539.4718448 ]

# %% [markdown]
# # Finding the location of the tip of the pen:

# %%
# the image space coordinates of the tip of the pen:
particleCoords = {0: (930.7, 1183.2),
                  1: (614.8, 1184.0)}

# %%
fig, ax = plt.subplots(1, 2)
fig.set_size_inches(10,8)

ax[0].imshow(img1, cmap='gray')
ax[1].imshow(img2, cmap='gray')

for k in particleCoords.keys():
    ax[k].plot(particleCoords[k][0], particleCoords[k][1], 'bo', ms=3)

# %%
# setting up an imaging system for stereo matching:
imgSys = img_system([cam1, cam2])

# %%
# solving stereo matching:

d_max = 500.0

results = imgSys.stereo_match(particleCoords, d_max)
print(results)
# Out:
# (array([149.10857807, -90.12286227,  85.17356472]), {0, 1}, 58.26765414121208)
